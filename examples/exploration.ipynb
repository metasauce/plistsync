# %%
# %reload_ext autoreload
# %autoreload 2

import os
os.environ["PSYNC_CONFIG_DIR"] = "../config/"

import plistsync
import plistsync.services.plex.api as papi

plistsync.services.plex.api.log.setLevel("DEBUG")

plistsync.services.plex.api.resolve_section_id("Music")  # Example usage to test the function


# takes some 5 seconds
res = plistsync.services.plex.api.fetch_tracks_by_path(
    "/media/music/clean/Etherwood, Grace Barton/Where The River Meets The Sea (feat. Grace Barton)/01 Where The River Meets The Sea (feat. Grace Barton) [1067kbps].flac",
    section_id=5,
)
res[0].get('title')
# Out:
# DEBUG:plistsync:Resolved section 5 with title 'Music'.
# 'If I Could'

# %%
playlist = plistsync.services.plex.api.fetch_playlist("109486")
playlist
# Out:
# {'ratingKey': '109486',
#  'key': '/playlists/109486/items',
#  'guid': 'com.plexapp.agents.none://0579aebf-a0f0-4ffb-bdc7-a69685a69adf',
#  'type': 'playlist',
#  'title': 'm-tech',
#  'summary': '',
#  'smart': False,
#  'playlistType': 'audio',
#  'composite': '/playlists/109486/composite/1755342632',
#  'duration': 9145000,
#  'leafCount': 21,
#  'addedAt': 1754943684,
#  'updatedAt': 1755342632}

# %%
res = plistsync.services.plex.api.fetch_tracks_by_id(106387)
res[0].get('title')
# Out:
# 'If I Could'

# %%
all_tracks = list(plistsync.services.plex.api.fetch_tracks(section_id=5, page_size=5000))

[t.get('title') for t in all_tracks[0:2]]
# Out:
# DEBUG:plistsync:Fetched 5000 of 17989 tracks from section 5.
# DEBUG:plistsync:Fetched 10000 of 17989 tracks from section 5.
# DEBUG:plistsync:Fetched 15000 of 17989 tracks from section 5.
# ['If I Could', 'Betamax']

# %%
res = plistsync.services.plex.api.fetch_tracks_by_id(106387, cache=all_tracks)
res[0].get('title')
# Out:
# 'If I Could'

# %%
res = plistsync.services.plex.api.fetch_tracks_by_path(
    "/media/music/clean/Etherwood, Grace Barton/Where The River Meets The Sea (feat. Grace Barton)/01 Where The River Meets The Sea (feat. Grace Barton) [1067kbps].flac",
    section_id=5,
    cache=all_tracks,
)
res[0].get('title')
# Out:
# 'Where The River Meets The Sea (feat. Grace Barton)'

# %%
plistsync.services.plex.api.fetch_playlist_items("109486")
# Out:
# [{'ratingKey': '109481',
#   'key': '/library/metadata/109481',
#   'parentRatingKey': '109480',
#   'grandparentRatingKey': '109479',
#   'guid': 'local://109481',
#   'parentGuid': 'local://109480',
#   'grandparentGuid': 'local://109479',
#   'parentStudio': 'Ame Err',
#   'type': 'track',
#   'title': 'Syntek',
#   'grandparentKey': '/library/metadata/109479',
#   'parentKey': '/library/metadata/109480',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Galucci, Panta',
#   'parentTitle': 'Syntek',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1754995831,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109480/thumb/1754678015',
#   'parentThumb': '/library/metadata/109480/thumb/1754678015',
#   'playlistItemID': 2427,
#   'duration': 292380,
#   'addedAt': 1754678014,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109139,
#     'duration': 292380,
#     'bitrate': 918,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155311,
#       'key': '/library/parts/155311/1755032176/file.flac',
#       'duration': 292380,
#       'file': '/media/music/clean/Galucci, Panta/Syntek/01 Syntek [918kbps].flac',
#       'size': 33717560,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Syntek',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109480/thumb/1754678015'}]},
#  {'ratingKey': '109474',
#   'key': '/library/metadata/109474',
#   'parentRatingKey': '109473',
#   'grandparentRatingKey': '109472',
#   'guid': 'local://109474',
#   'parentGuid': 'local://109473',
#   'grandparentGuid': 'plex://artist/5d07bc0d403c6402904b1d54',
#   'parentStudio': '11:11',
#   'type': 'track',
#   'title': 'Melodic Techno, Pt1',
#   'grandparentKey': '/library/metadata/109472',
#   'parentKey': '/library/metadata/109473',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Industrial Sound',
#   'parentTitle': 'Melodic Techno Bangers',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1754996306,
#   'parentYear': 2024,
#   'thumb': '/library/metadata/109473/thumb/1754677997',
#   'parentThumb': '/library/metadata/109473/thumb/1754677997',
#   'grandparentThumb': '/library/metadata/109472/thumb/1754678002',
#   'playlistItemID': 2428,
#   'duration': 670153,
#   'addedAt': 1754677996,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109134,
#     'duration': 670153,
#     'bitrate': 827,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155306,
#       'key': '/library/parts/155306/1755032181/file.flac',
#       'duration': 670153,
#       'file': '/media/music/clean/Industrial Sound/Melodic Techno Bangers/01 Melodic Techno, Pt1 [827kbps].flac',
#       'size': 69498045,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melodic Techno, Pt1',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109472/thumb/1754678002'}]},
#  {'ratingKey': '109475',
#   'key': '/library/metadata/109475',
#   'parentRatingKey': '109473',
#   'grandparentRatingKey': '109472',
#   'guid': 'local://109475',
#   'parentGuid': 'local://109473',
#   'grandparentGuid': 'plex://artist/5d07bc0d403c6402904b1d54',
#   'parentStudio': '11:11',
#   'type': 'track',
#   'title': 'Melodic Techno, Pt2',
#   'grandparentKey': '/library/metadata/109472',
#   'parentKey': '/library/metadata/109473',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Industrial Sound',
#   'parentTitle': 'Melodic Techno Bangers',
#   'summary': '',
#   'index': 2,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755001067,
#   'parentYear': 2024,
#   'thumb': '/library/metadata/109473/thumb/1754677997',
#   'parentThumb': '/library/metadata/109473/thumb/1754677997',
#   'grandparentThumb': '/library/metadata/109472/thumb/1754678002',
#   'playlistItemID': 2429,
#   'duration': 618461,
#   'addedAt': 1754677996,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109135,
#     'duration': 618461,
#     'bitrate': 813,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155307,
#       'key': '/library/parts/155307/1755032185/file.flac',
#       'duration': 618461,
#       'file': '/media/music/clean/Industrial Sound/Melodic Techno Bangers/02 Melodic Techno, Pt2 [813kbps].flac',
#       'size': 63071788,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melodic Techno, Pt2',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109472/thumb/1754678002'}]},
#  {'ratingKey': '109476',
#   'key': '/library/metadata/109476',
#   'parentRatingKey': '109473',
#   'grandparentRatingKey': '109472',
#   'guid': 'local://109476',
#   'parentGuid': 'local://109473',
#   'grandparentGuid': 'plex://artist/5d07bc0d403c6402904b1d54',
#   'parentStudio': '11:11',
#   'type': 'track',
#   'title': 'Melodic Techno, Pt3',
#   'grandparentKey': '/library/metadata/109472',
#   'parentKey': '/library/metadata/109473',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Industrial Sound',
#   'parentTitle': 'Melodic Techno Bangers',
#   'summary': '',
#   'index': 3,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755001731,
#   'parentYear': 2024,
#   'thumb': '/library/metadata/109473/thumb/1754677997',
#   'parentThumb': '/library/metadata/109473/thumb/1754677997',
#   'grandparentThumb': '/library/metadata/109472/thumb/1754678002',
#   'playlistItemID': 2430,
#   'duration': 731076,
#   'addedAt': 1754677996,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109136,
#     'duration': 731076,
#     'bitrate': 923,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155308,
#       'key': '/library/parts/155308/1755032190/file.flac',
#       'duration': 731076,
#       'file': '/media/music/clean/Industrial Sound/Melodic Techno Bangers/03 Melodic Techno, Pt3 [922kbps].flac',
#       'size': 84514292,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melodic Techno, Pt3',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109472/thumb/1754678002'}]},
#  {'ratingKey': '109477',
#   'key': '/library/metadata/109477',
#   'parentRatingKey': '109473',
#   'grandparentRatingKey': '109472',
#   'guid': 'local://109477',
#   'parentGuid': 'local://109473',
#   'grandparentGuid': 'plex://artist/5d07bc0d403c6402904b1d54',
#   'parentStudio': '11:11',
#   'type': 'track',
#   'title': 'Melodic Techno, Pt4',
#   'grandparentKey': '/library/metadata/109472',
#   'parentKey': '/library/metadata/109473',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Industrial Sound',
#   'parentTitle': 'Melodic Techno Bangers',
#   'summary': '',
#   'index': 4,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755002477,
#   'parentYear': 2024,
#   'thumb': '/library/metadata/109473/thumb/1754677997',
#   'parentThumb': '/library/metadata/109473/thumb/1754677997',
#   'grandparentThumb': '/library/metadata/109472/thumb/1754678002',
#   'playlistItemID': 2431,
#   'duration': 742153,
#   'addedAt': 1754677996,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109137,
#     'duration': 742153,
#     'bitrate': 992,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155309,
#       'key': '/library/parts/155309/1755032195/file.flac',
#       'duration': 742153,
#       'file': '/media/music/clean/Industrial Sound/Melodic Techno Bangers/04 Melodic Techno, Pt4 [991kbps].flac',
#       'size': 92220480,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melodic Techno, Pt4',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109472/thumb/1754678002'}]},
#  {'ratingKey': '109478',
#   'key': '/library/metadata/109478',
#   'parentRatingKey': '109473',
#   'grandparentRatingKey': '109472',
#   'guid': 'local://109478',
#   'parentGuid': 'local://109473',
#   'grandparentGuid': 'plex://artist/5d07bc0d403c6402904b1d54',
#   'parentStudio': '11:11',
#   'type': 'track',
#   'title': 'Melodic Techno, Pt5',
#   'grandparentKey': '/library/metadata/109472',
#   'parentKey': '/library/metadata/109473',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Industrial Sound',
#   'parentTitle': 'Melodic Techno Bangers',
#   'summary': '',
#   'index': 5,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755003189,
#   'parentYear': 2024,
#   'thumb': '/library/metadata/109473/thumb/1754677997',
#   'parentThumb': '/library/metadata/109473/thumb/1754677997',
#   'grandparentThumb': '/library/metadata/109472/thumb/1754678002',
#   'playlistItemID': 2432,
#   'duration': 684923,
#   'addedAt': 1754677996,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109138,
#     'duration': 684923,
#     'bitrate': 886,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155310,
#       'key': '/library/parts/155310/1755032199/file.flac',
#       'duration': 684923,
#       'file': '/media/music/clean/Industrial Sound/Melodic Techno Bangers/05 Melodic Techno, Pt5 [885kbps].flac',
#       'size': 76052825,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melodic Techno, Pt5',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109472/thumb/1754678002'}]},
#  {'ratingKey': '109470',
#   'key': '/library/metadata/109470',
#   'parentRatingKey': '109469',
#   'grandparentRatingKey': '109468',
#   'guid': 'local://109470',
#   'parentGuid': 'local://109469',
#   'grandparentGuid': 'plex://artist/5d07bd73403c6402905e8e99',
#   'parentStudio': 'Polaris',
#   'type': 'track',
#   'title': 'Kamatoro',
#   'grandparentKey': '/library/metadata/109468',
#   'parentKey': '/library/metadata/109469',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'AFFKT',
#   'parentTitle': 'Kamatoro',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755003706,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109469/thumb/1754677902',
#   'parentThumb': '/library/metadata/109469/thumb/1754677902',
#   'grandparentThumb': '/library/metadata/109468/thumb/1754677906',
#   'playlistItemID': 2433,
#   'duration': 342581,
#   'addedAt': 1754677901,
#   'updatedAt': 1754677902,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109132,
#     'duration': 342581,
#     'bitrate': 1054,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155304,
#       'key': '/library/parts/155304/1755032148/file.flac',
#       'duration': 342581,
#       'file': '/media/music/clean/AFFKT/Kamatoro/01 Kamatoro [1054kbps].flac',
#       'size': 45293464,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Kamatoro',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109468/thumb/1754677906'}],
#   'Genre': [{'tag': 'Tech House'}, {'tag': 'Deep House'}]},
#  {'ratingKey': '109471',
#   'key': '/library/metadata/109471',
#   'parentRatingKey': '109469',
#   'grandparentRatingKey': '109468',
#   'guid': 'local://109471',
#   'parentGuid': 'local://109469',
#   'grandparentGuid': 'plex://artist/5d07bd73403c6402905e8e99',
#   'parentStudio': 'Polaris',
#   'type': 'track',
#   'title': 'Umukai',
#   'grandparentKey': '/library/metadata/109468',
#   'parentKey': '/library/metadata/109469',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'AFFKT',
#   'parentTitle': 'Kamatoro',
#   'summary': '',
#   'index': 2,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755004049,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109469/thumb/1754677902',
#   'parentThumb': '/library/metadata/109469/thumb/1754677902',
#   'grandparentThumb': '/library/metadata/109468/thumb/1754677906',
#   'playlistItemID': 2434,
#   'duration': 343637,
#   'addedAt': 1754677901,
#   'updatedAt': 1754677902,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109133,
#     'duration': 343637,
#     'bitrate': 1049,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155305,
#       'key': '/library/parts/155305/1755032151/file.flac',
#       'duration': 343637,
#       'file': '/media/music/clean/AFFKT/Kamatoro/02 Umukai [1049kbps].flac',
#       'size': 45237325,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Umukai',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109468/thumb/1754677906'}],
#   'Genre': [{'tag': 'Tech House'}, {'tag': 'Deep House'}]},
#  {'ratingKey': '109467',
#   'key': '/library/metadata/109467',
#   'parentRatingKey': '109466',
#   'grandparentRatingKey': '109465',
#   'guid': 'local://109467',
#   'parentGuid': 'local://109466',
#   'grandparentGuid': 'local://109465',
#   'parentStudio': 'Stil Vor Talent Records',
#   'type': 'track',
#   'title': 'Space Base',
#   'grandparentKey': '/library/metadata/109465',
#   'parentKey': '/library/metadata/109466',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Oliver Koletzki, Frida Darko',
#   'parentTitle': 'Space Base',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755004377,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109466/thumb/1754677879',
#   'parentThumb': '/library/metadata/109466/thumb/1754677879',
#   'playlistItemID': 2435,
#   'duration': 327825,
#   'addedAt': 1754677878,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109131,
#     'duration': 327825,
#     'bitrate': 856,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155303,
#       'key': '/library/parts/155303/1755032206/file.flac',
#       'duration': 327825,
#       'file': '/media/music/clean/Oliver Koletzki, Frida Darko/Space Base/01 Space Base [856kbps].flac',
#       'size': 35222693,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Space Base',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109466/thumb/1754677879'}]},
#  {'ratingKey': '109461',
#   'key': '/library/metadata/109461',
#   'parentRatingKey': '109460',
#   'grandparentRatingKey': '109459',
#   'guid': 'local://109461',
#   'parentGuid': 'local://109460',
#   'grandparentGuid': 'plex://artist/669f04434849cdfbf4a158dc',
#   'parentStudio': 'Sincopat',
#   'type': 'track',
#   'title': 'Nikita',
#   'grandparentKey': '/library/metadata/109459',
#   'parentKey': '/library/metadata/109460',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Ary Sya',
#   'parentTitle': 'Nikita',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755004705,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109460/thumb/1754677838',
#   'parentThumb': '/library/metadata/109460/thumb/1754677838',
#   'grandparentThumb': '/library/metadata/109459/thumb/1754677841',
#   'playlistItemID': 2436,
#   'duration': 326749,
#   'addedAt': 1754677837,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109127,
#     'duration': 326749,
#     'bitrate': 975,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155299,
#       'key': '/library/parts/155299/1755032165/file.flac',
#       'duration': 326749,
#       'file': '/media/music/clean/Ary Sya/Nikita/01 Nikita [974kbps].flac',
#       'size': 39993036,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Nikita',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109459/thumb/1754677841'}]},
#  {'ratingKey': '109462',
#   'key': '/library/metadata/109462',
#   'parentRatingKey': '109460',
#   'grandparentRatingKey': '109459',
#   'guid': 'local://109462',
#   'parentGuid': 'local://109460',
#   'grandparentGuid': 'plex://artist/669f04434849cdfbf4a158dc',
#   'parentStudio': 'Sincopat',
#   'type': 'track',
#   'title': 'Nikita - James Harcourt Remix',
#   'grandparentKey': '/library/metadata/109459',
#   'parentKey': '/library/metadata/109460',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Ary Sya',
#   'parentTitle': 'Nikita',
#   'originalTitle': 'Ary Sya, James Harcourt',
#   'summary': '',
#   'index': 2,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755005016,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109460/thumb/1754677838',
#   'parentThumb': '/library/metadata/109460/thumb/1754677838',
#   'grandparentThumb': '/library/metadata/109459/thumb/1754677841',
#   'playlistItemID': 2437,
#   'duration': 295854,
#   'addedAt': 1754677837,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109128,
#     'duration': 295854,
#     'bitrate': 851,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155300,
#       'key': '/library/parts/155300/1755032167/file.flac',
#       'duration': 295854,
#       'file': '/media/music/clean/Ary Sya/Nikita/02 Nikita - James Harcourt Remix [850kbps].flac',
#       'size': 31647789,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Nikita - James Harcourt Remix',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109459/thumb/1754677841'}]},
#  {'ratingKey': '109463',
#   'key': '/library/metadata/109463',
#   'parentRatingKey': '109460',
#   'grandparentRatingKey': '109459',
#   'guid': 'local://109463',
#   'parentGuid': 'local://109460',
#   'grandparentGuid': 'plex://artist/669f04434849cdfbf4a158dc',
#   'parentStudio': 'Sincopat',
#   'type': 'track',
#   'title': 'Akari',
#   'grandparentKey': '/library/metadata/109459',
#   'parentKey': '/library/metadata/109460',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Ary Sya',
#   'parentTitle': 'Nikita',
#   'summary': '',
#   'index': 3,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755005358,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109460/thumb/1754677838',
#   'parentThumb': '/library/metadata/109460/thumb/1754677838',
#   'grandparentThumb': '/library/metadata/109459/thumb/1754677841',
#   'playlistItemID': 2438,
#   'duration': 374164,
#   'addedAt': 1754677837,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109129,
#     'duration': 374164,
#     'bitrate': 969,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155301,
#       'key': '/library/parts/155301/1755032170/file.flac',
#       'duration': 374164,
#       'file': '/media/music/clean/Ary Sya/Nikita/03 Akari [969kbps].flac',
#       'size': 45521964,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Akari',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109459/thumb/1754677841'}]},
#  {'ratingKey': '109464',
#   'key': '/library/metadata/109464',
#   'parentRatingKey': '109460',
#   'grandparentRatingKey': '109459',
#   'guid': 'local://109464',
#   'parentGuid': 'local://109460',
#   'grandparentGuid': 'plex://artist/669f04434849cdfbf4a158dc',
#   'parentStudio': 'Sincopat',
#   'type': 'track',
#   'title': 'Melon',
#   'grandparentKey': '/library/metadata/109459',
#   'parentKey': '/library/metadata/109460',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Ary Sya',
#   'parentTitle': 'Nikita',
#   'summary': '',
#   'index': 4,
#   'parentIndex': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755005732,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109460/thumb/1754677838',
#   'parentThumb': '/library/metadata/109460/thumb/1754677838',
#   'grandparentThumb': '/library/metadata/109459/thumb/1754677841',
#   'playlistItemID': 2439,
#   'duration': 379500,
#   'addedAt': 1754677837,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109130,
#     'duration': 379500,
#     'bitrate': 1006,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155302,
#       'key': '/library/parts/155302/1755032173/file.flac',
#       'duration': 379500,
#       'file': '/media/music/clean/Ary Sya/Nikita/04 Melon [1005kbps].flac',
#       'size': 47907959,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Melon',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109459/thumb/1754677841'}]},
#  {'ratingKey': '109455',
#   'key': '/library/metadata/109455',
#   'parentRatingKey': '109454',
#   'grandparentRatingKey': '109453',
#   'guid': 'plex://track/681c6834bf5c1ff93cd10823',
#   'parentGuid': 'plex://album/681c5a4abf5c1ff93ccf2e07',
#   'grandparentGuid': 'plex://artist/6717b3907bd04da5be2cadc8',
#   'parentStudio': 'Midnight People',
#   'type': 'track',
#   'title': 'See You Later Sanity',
#   'grandparentKey': '/library/metadata/109453',
#   'parentKey': '/library/metadata/109454',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Aristo G',
#   'parentTitle': 'See You Later Sanity',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'ratingCount': 26,
#   'viewCount': 2,
#   'lastViewedAt': 1755006112,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109454/thumb/1754677795',
#   'parentThumb': '/library/metadata/109454/thumb/1754677795',
#   'grandparentThumb': '/library/metadata/109453/thumb/1754677793',
#   'playlistItemID': 2440,
#   'duration': 381109,
#   'addedAt': 1754677792,
#   'updatedAt': 1754677795,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109123,
#     'duration': 381109,
#     'bitrate': 837,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155295,
#       'key': '/library/parts/155295/1755032154/file.flac',
#       'duration': 381109,
#       'file': '/media/music/clean/Aristo G/See You Later Sanity/01 See You Later Sanity [837kbps].flac',
#       'size': 40027497,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'See You Later Sanity',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109453/thumb/1754677793'}]},
#  {'ratingKey': '109456',
#   'key': '/library/metadata/109456',
#   'parentRatingKey': '109454',
#   'grandparentRatingKey': '109453',
#   'guid': 'plex://track/681c6835bf5c1ff93cd108f0',
#   'parentGuid': 'plex://album/681c5a4abf5c1ff93ccf2e07',
#   'grandparentGuid': 'plex://artist/6717b3907bd04da5be2cadc8',
#   'parentStudio': 'Midnight People',
#   'type': 'track',
#   'title': 'When Hearts Collide',
#   'grandparentKey': '/library/metadata/109453',
#   'parentKey': '/library/metadata/109454',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Aristo G',
#   'parentTitle': 'See You Later Sanity',
#   'summary': '',
#   'index': 2,
#   'parentIndex': 1,
#   'ratingCount': 4,
#   'viewCount': 2,
#   'lastViewedAt': 1755006539,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109454/thumb/1754677795',
#   'parentThumb': '/library/metadata/109454/thumb/1754677795',
#   'grandparentThumb': '/library/metadata/109453/thumb/1754677793',
#   'playlistItemID': 2441,
#   'duration': 468687,
#   'addedAt': 1754677792,
#   'updatedAt': 1754677795,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109124,
#     'duration': 468687,
#     'bitrate': 910,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155296,
#       'key': '/library/parts/155296/1755032157/file.flac',
#       'duration': 468687,
#       'file': '/media/music/clean/Aristo G/See You Later Sanity/02 When Hearts Collide [909kbps].flac',
#       'size': 53455765,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'When Hearts Collide',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109453/thumb/1754677793'}]},
#  {'ratingKey': '109457',
#   'key': '/library/metadata/109457',
#   'parentRatingKey': '109454',
#   'grandparentRatingKey': '109453',
#   'guid': 'plex://track/681c6835bf5c1ff93cd108b7',
#   'parentGuid': 'plex://album/681c5a4abf5c1ff93ccf2e07',
#   'grandparentGuid': 'plex://artist/6717b3907bd04da5be2cadc8',
#   'parentStudio': 'Midnight People',
#   'type': 'track',
#   'title': 'See You Later Sanity - Dub Mix',
#   'grandparentKey': '/library/metadata/109453',
#   'parentKey': '/library/metadata/109454',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Aristo G',
#   'parentTitle': 'See You Later Sanity',
#   'summary': '',
#   'index': 3,
#   'parentIndex': 1,
#   'ratingCount': 1,
#   'viewCount': 2,
#   'lastViewedAt': 1755006962,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109454/thumb/1754677795',
#   'parentThumb': '/library/metadata/109454/thumb/1754677795',
#   'grandparentThumb': '/library/metadata/109453/thumb/1754677793',
#   'playlistItemID': 2442,
#   'duration': 381051,
#   'addedAt': 1754677792,
#   'updatedAt': 1754677795,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109125,
#     'duration': 381051,
#     'bitrate': 834,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155297,
#       'key': '/library/parts/155297/1755032160/file.flac',
#       'duration': 381051,
#       'file': '/media/music/clean/Aristo G/See You Later Sanity/03 See You Later Sanity - Dub Mix [833kbps].flac',
#       'size': 39855219,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'See You Later Sanity - Dub Mix',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109453/thumb/1754677793'}]},
#  {'ratingKey': '109458',
#   'key': '/library/metadata/109458',
#   'parentRatingKey': '109454',
#   'grandparentRatingKey': '109453',
#   'guid': 'plex://track/681c6834bf5c1ff93cd1089e',
#   'parentGuid': 'plex://album/681c5a4abf5c1ff93ccf2e07',
#   'grandparentGuid': 'plex://artist/6717b3907bd04da5be2cadc8',
#   'parentStudio': 'Midnight People',
#   'type': 'track',
#   'title': 'When Hearts Collide - Dub Mix',
#   'grandparentKey': '/library/metadata/109453',
#   'parentKey': '/library/metadata/109454',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Aristo G',
#   'parentTitle': 'See You Later Sanity',
#   'summary': '',
#   'index': 4,
#   'parentIndex': 1,
#   'viewCount': 3,
#   'lastViewedAt': 1755070454,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109454/thumb/1754677795',
#   'parentThumb': '/library/metadata/109454/thumb/1754677795',
#   'grandparentThumb': '/library/metadata/109453/thumb/1754677793',
#   'playlistItemID': 2443,
#   'duration': 468671,
#   'addedAt': 1754677792,
#   'updatedAt': 1754677795,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109126,
#     'duration': 468671,
#     'bitrate': 918,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155298,
#       'key': '/library/parts/155298/1755032163/file.flac',
#       'duration': 468671,
#       'file': '/media/music/clean/Aristo G/See You Later Sanity/04 When Hearts Collide - Dub Mix [917kbps].flac',
#       'size': 53935140,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'When Hearts Collide - Dub Mix',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109453/thumb/1754677793'}]},
#  {'ratingKey': '109450',
#   'key': '/library/metadata/109450',
#   'parentRatingKey': '109449',
#   'grandparentRatingKey': '109448',
#   'guid': 'local://109450',
#   'parentGuid': 'local://109449',
#   'grandparentGuid': 'local://109448',
#   'parentStudio': 'Jannowitz Records',
#   'type': 'track',
#   'title': 'I Remember Those Nights',
#   'grandparentKey': '/library/metadata/109448',
#   'parentKey': '/library/metadata/109449',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'SNYL, David LeSal, MMYYLO',
#   'parentTitle': 'Future Echoes',
#   'originalTitle': 'SNYL, David LeSal',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 1,
#   'lastViewedAt': 1754993815,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109449/thumb/1754677727',
#   'parentThumb': '/library/metadata/109449/thumb/1754677727',
#   'playlistItemID': 2444,
#   'duration': 303779,
#   'addedAt': 1754677726,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109120,
#     'duration': 303779,
#     'bitrate': 869,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155292,
#       'key': '/library/parts/155292/1755032210/file.flac',
#       'duration': 303779,
#       'file': '/media/music/clean/SNYL, David LeSal, MMYYLO/Future Echoes/01 I Remember Those Nights [869kbps].flac',
#       'size': 33153474,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'I Remember Those Nights',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109449/thumb/1754677727'}]},
#  {'ratingKey': '109451',
#   'key': '/library/metadata/109451',
#   'parentRatingKey': '109449',
#   'grandparentRatingKey': '109448',
#   'guid': 'local://109451',
#   'parentGuid': 'local://109449',
#   'grandparentGuid': 'local://109448',
#   'parentStudio': 'Jannowitz Records',
#   'type': 'track',
#   'title': 'Give Me the Process',
#   'grandparentKey': '/library/metadata/109448',
#   'parentKey': '/library/metadata/109449',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'SNYL, David LeSal, MMYYLO',
#   'parentTitle': 'Future Echoes',
#   'originalTitle': 'MMYYLO',
#   'summary': '',
#   'index': 2,
#   'parentIndex': 1,
#   'viewCount': 1,
#   'lastViewedAt': 1754994196,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109449/thumb/1754677727',
#   'parentThumb': '/library/metadata/109449/thumb/1754677727',
#   'playlistItemID': 2445,
#   'duration': 448000,
#   'addedAt': 1754677726,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109121,
#     'duration': 448000,
#     'bitrate': 948,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155293,
#       'key': '/library/parts/155293/1755032213/file.flac',
#       'duration': 448000,
#       'file': '/media/music/clean/SNYL, David LeSal, MMYYLO/Future Echoes/02 Give Me the Process [948kbps].flac',
#       'size': 53280359,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Give Me the Process',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109449/thumb/1754677727'}]},
#  {'ratingKey': '109452',
#   'key': '/library/metadata/109452',
#   'parentRatingKey': '109449',
#   'grandparentRatingKey': '109448',
#   'guid': 'local://109452',
#   'parentGuid': 'local://109449',
#   'grandparentGuid': 'local://109448',
#   'parentStudio': 'Jannowitz Records',
#   'type': 'track',
#   'title': 'Future Echoes',
#   'grandparentKey': '/library/metadata/109448',
#   'parentKey': '/library/metadata/109449',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'SNYL, David LeSal, MMYYLO',
#   'parentTitle': 'Future Echoes',
#   'originalTitle': 'SNYL, MMYYLO',
#   'summary': '',
#   'index': 3,
#   'parentIndex': 1,
#   'viewCount': 1,
#   'lastViewedAt': 1754994613,
#   'parentYear': 2025,
#   'thumb': '/library/metadata/109449/thumb/1754677727',
#   'parentThumb': '/library/metadata/109449/thumb/1754677727',
#   'playlistItemID': 2446,
#   'duration': 400000,
#   'addedAt': 1754677726,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109122,
#     'duration': 400000,
#     'bitrate': 920,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155294,
#       'key': '/library/parts/155294/1755032216/file.flac',
#       'duration': 400000,
#       'file': '/media/music/clean/SNYL, David LeSal, MMYYLO/Future Echoes/03 Future Echoes [920kbps].flac',
#       'size': 46163982,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'Future Echoes',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109449/thumb/1754677727'}]},
#  {'ratingKey': '109447',
#   'key': '/library/metadata/109447',
#   'parentRatingKey': '109446',
#   'grandparentRatingKey': '109445',
#   'guid': 'local://109447',
#   'parentGuid': 'local://109446',
#   'grandparentGuid': 'local://109445',
#   'parentStudio': 'Kontor Records',
#   'type': 'track',
#   'title': 'I Can Feel',
#   'grandparentKey': '/library/metadata/109445',
#   'parentKey': '/library/metadata/109446',
#   'librarySectionTitle': 'Music',
#   'librarySectionID': 5,
#   'librarySectionKey': '/library/sections/5',
#   'grandparentTitle': 'Leony, Niklas Dee, VIZE',
#   'parentTitle': 'I Can Feel',
#   'summary': '',
#   'index': 1,
#   'parentIndex': 1,
#   'viewCount': 1,
#   'lastViewedAt': 1754994904,
#   'parentYear': 2023,
#   'thumb': '/library/metadata/109446/thumb/1754677641',
#   'parentThumb': '/library/metadata/109446/thumb/1754677641',
#   'playlistItemID': 2447,
#   'duration': 173360,
#   'addedAt': 1754677640,
#   'musicAnalysisVersion': '1',
#   'Media': [{'id': 109119,
#     'duration': 173360,
#     'bitrate': 906,
#     'audioChannels': 2,
#     'audioCodec': 'flac',
#     'container': 'flac',
#     'hasVoiceActivity': False,
#     'Part': [{'id': 155291,
#       'key': '/library/parts/155291/1755032201/file.flac',
#       'duration': 173360,
#       'file': '/media/music/clean/Leony, Niklas Dee, VIZE/I Can Feel/01 I Can Feel [905kbps].flac',
#       'size': 19756249,
#       'container': 'flac',
#       'hasThumbnail': '1'}]}],
#   'Image': [{'alt': 'I Can Feel',
#     'type': 'coverPoster',
#     'url': '/library/metadata/109446/thumb/1754677641'}]}]

# %%
# papi.resolve_playlist_id("_plistsync")
papi.fetch_playlist(109614)
# Out:
# {'ratingKey': '109614',
#  'key': '/playlists/109614/items',
#  'guid': 'com.plexapp.agents.none://04300454-cfc9-4404-b9b7-e60409220a13',
#  'type': 'playlist',
#  'title': '_plistsync',
#  'summary': '',
#  'smart': False,
#  'playlistType': 'audio',
#  'composite': '/playlists/109614/composite/1755342643',
#  'duration': 1256000,
#  'leafCount': 3,
#  'addedAt': 1755340141,
#  'updatedAt': 1755342643}

# %%
# get the root path of the section
plistsync.services.plex.api.request(f"/library/sections")
plistsync.services.plex.api.fetch_section_root_path(f"5")
plistsync.services.plex.api.request(
            "/identity"
        )

# %%
res = papi.insert_track_into_playlist_by_id(
    track_id=109481,
    # track_id=106387,
    playlist_id=109614,
)
res
# Out:
# DEBUG:plistsync:Inserting track 109481 into playlist 109614.
# {'MediaContainer': {'size': 1,
#   'leafCountAdded': 0,
#   'leafCountRequested': 1,
#   'Metadata': [{'ratingKey': '109614',
#     'key': '/playlists/109614/items',
#     'guid': 'com.plexapp.agents.none://04300454-cfc9-4404-b9b7-e60409220a13',
#     'type': 'playlist',
#     'title': '_plistsync',
#     'summary': '',
#     'smart': False,
#     'playlistType': 'audio',
#     'composite': '/playlists/109614/composite/1755342644',
#     'duration': 1256000,
#     'leafCount': 3,
#     'addedAt': 1755340141,
#     'updatedAt': 1755342644}]}}

# %%
pl = plistsync.services.plex.collection.PlexPlaylistCollection("_plistsync")

pl.insert_by_id(109481)
# Out:
# DEBUG:plistsync:Inserting track 109481 into playlist 109614.
# {'MediaContainer': {'size': 1,
#   'leafCountAdded': 0,
#   'leafCountRequested': 1,
#   'Metadata': [{'ratingKey': '109614',
#     'key': '/playlists/109614/items',
#     'guid': 'com.plexapp.agents.none://04300454-cfc9-4404-b9b7-e60409220a13',
#     'type': 'playlist',
#     'title': '_plistsync',
#     'summary': '',
#     'smart': False,
#     'playlistType': 'audio',
#     'composite': '/playlists/109614/composite/1755342644',
#     'duration': 1256000,
#     'leafCount': 3,
#     'addedAt': 1755340141,
#     'updatedAt': 1755342644}]}}

# %%
plistsync.services.plex.track.log.setLevel("INFO")
pl.library_collection = plistsync.services.plex.collection.PlexLibrarySectionCollection("Music")
pl.insert_by_path("/media/music/clean/Industrial Sound/Melodic Techno Bangers/01 Melodic Techno, Pt1 [827kbps].flac")
# Out:
# {'MediaContainer': {'size': 1,
#   'leafCountAdded': 0,
#   'leafCountRequested': 1,
#   'Metadata': [{'ratingKey': '109614',
#     'key': '/playlists/109614/items',
#     'guid': 'com.plexapp.agents.none://04300454-cfc9-4404-b9b7-e60409220a13',
#     'type': 'playlist',
#     'title': '_plistsync',
#     'summary': '',
#     'smart': False,
#     'playlistType': 'audio',
#     'composite': '/playlists/109614/composite/1755342653',
#     'duration': 1256000,
#     'leafCount': 3,
#     'addedAt': 1755340141,
#     'updatedAt': 1755342653}]}}
